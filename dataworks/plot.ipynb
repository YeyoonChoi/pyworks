# %%
import matplotlib.pyplot as plt

# 데이터 준비
x = [1, 2, 3, 4, 5]
y = [2, 3, 5, 7, 11]

# 한글 글꼴 (내컴퓨터 > System > fonts)
plt.rc('font', family='Malgun Gothic')
    
# 선 그래프
plt.plot(x, y, label='Prime Numbers')
plt.title("선 그래프")
plt.legend() # 범례

# 출력
plt.show()
