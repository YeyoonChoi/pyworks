# %%
import pandas as pd

food = pd.DataFrame({
    "메뉴": ["김밥", "비빔밥", "자장면", "우동", "김밥", "자장면", "김밥"],
    "가격": [3000, 7000, 5500, 5500, 3500, 6000, 4000],
    "분류": ["한식", "한식", "중식", "일식", "한식", "중식", "한식"]
})
# print(food)

# 데이터의 일부만 검색 - head(), tail()
# print(food.head())
# print(food.tail())

# 데이터 정보 - info()
food.info()

# 요악 정보 -describe(). 숫자만 나오는 것
food.describe() # 기본 - 수치형 칼럼 요약
food.describe(include='object') # 문자형 칼럼 요약
food.describe(include='number') # 수치형 칼럼 요약

# 고유한 값의 개수
food["메뉴"].value_counts()
food["분류"].value_counts()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7 entries, 0 to 6
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   메뉴      7 non-null      object
#  1   가격      7 non-null      int64
#  2   분류      7 non-null      object
# dtypes: int64(1), object(2)
# memory usage: 296.0+ bytes
# 한식    4
# 중식    2
# 일식    1
# Name: 분류, dtype: int64

# %%
# 조건 검색
# 가격이 4000원 미만인 음식 정보
result1 = (food["가격"] < 4000)
print(food[result1])

# 메뉴가 김밥이 아닌 음식 정보
print(food[food["메뉴"] !="김밥"])

# 가격을 내림차순 정렬 - sort_values()
print(food.sort_values("가격", ascending=False))
# Out:
#    메뉴    가격  분류
# 0  김밥  3000  한식
# 4  김밥  3500  한식
#     메뉴    가격  분류
# 1  비빔밥  7000  한식
# 2  자장면  5500  중식
# 3   우동  5500  일식
# 5  자장면  6000  중식
#     메뉴    가격  분류
# 1  비빔밥  7000  한식
# 5  자장면  6000  중식
# 2  자장면  5500  중식
# 3   우동  5500  일식
# 6   김밥  4000  한식
# 4   김밥  3500  한식
# 0   김밥  3000  한식

# %%
# 파이썬 : sum(리스트), Len(리스트)
# 집계(통계) 함수
food["판매개수"] =  [30, 70, 55, 55, 35, 60, 40]
print(food)

print(food["판매개수"].count()) # 개수
print(food["판매개수"].sum()) # 합계
print(round(food["판매개수"].mean(), 2)) # 평균 (소수 둘째자리)

# 최빈값 - 자주 등장하는 값 : mode()
print(food["메뉴"].mode()) # 시리즈 형
print(food["메뉴"].mode()[0]) # 김밥

# 그루핑 - groupby()
# 분류별 판매개수의 합계
print(food.groupby("분류")["판매개수"].sum())

# 메뉴벌 판매개수의 최대값 계산
print(food.groupby("메뉴")["판매개수"].max())
# Out:
#     메뉴    가격  분류  판매개수
# 0   김밥  3000  한식    30
# 1  비빔밥  7000  한식    70
# 2  자장면  5500  중식    55
# 3   우동  5500  일식    55
# 4   김밥  3500  한식    35
# 5  자장면  6000  중식    60
# 6   김밥  4000  한식    40
# 7
# 345
# 49.29
# 0    김밥
# Name: 메뉴, dtype: object
# 김밥
# 분류
# 일식     55
# 중식    115
# 한식    175
# Name: 판매개수, dtype: int64
# 메뉴
# 김밥     40
# 비빔밥    70
# 우동     55
# 자장면    60
# Name: 판매개수, dtype: int64

# %%
# food 데이터프레임 만들기
food.to_csv("datas/food.csv", index=False)

# %%
# 엑셀 파일 읽기 - read_excel(파일경로)
import pandas as pd

df = pd.read_excel("datas/budget.xlsx")
df
# print(df.head(10))

df.info()

df.describe()

# 유형별 금액의 합)
result1 = df.groupby("유형")["금액"].sum()
print(result1)

# 분류별 거래 건수
result2 = df.groupby("분류").size().reset_index(name="거래건수")
print(result2)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 18 entries, 0 to 17
# Data columns (total 5 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   날짜      18 non-null     object
#  1   유형      18 non-null     object
#  2   분류      18 non-null     object
#  3   항목      18 non-null     object
#  4   금액      18 non-null     int64
# dtypes: int64(1), object(4)
# memory usage: 848.0+ bytes
# 유형
# 수입    2900000
# 지출     940500
# Name: 금액, dtype: int64
#    분류  거래건수
# 0  교통     3
# 1  급여     1
# 2  문화     2
# 3  생활     2
# 4  식비     6
# 5  용돈     1
# 6  의료     1
# 7  주거     1
# 8  통신     1
